# %% [markdown]
# # Program to create a file and write some title and its related data to show them in pie chart.
#
# Enter the filename:
# -> new_file.txt

# %%
fname=input("Enter the filename\n")
# Out:
# Enter the filename
# data.txt

# %% [raw]
# Enter the five data in file with its label
# In this format
#  Title:Number example Maths:95
#
#  -> Pen:10
#  -> Pencil:20
#  -> Scale:50
#  -> Eraser:20
#  -> Sharpner:15

# %%
print("Enter the five data in file with its label\nIn this format\n Title:Number example Maths:95")
with open(fname,"w") as fn: #fn=open(fname,"w+")
    for i in range(0,5):
        x=input()
        fn.write(str(x)+'\n')
#
# Out:
# Enter the five data in file with its label
# In this format
#  Title:Number example Maths:95
# Pen:10
# Pen:10
# Pen:10
# Pen:10
# Pen:10

# %%
label=[]
title=[]
with open(fname,"r+") as fr:

        for line in fr:
            print(line)
            loc=line.rfind(':')
            t=line[0:loc]
            title.append(str(t))
            l=line[loc+1:]
            label.append(int(l))
            
print(title)
print(label)

fr.close()
# loc=str_new.rfind(":")
# Out:
# Pen:10
#
# Pen:10
#
# Pen:10
#
# Pen:10
#
# Pen:10
#
# ['Pen', 'Pen', 'Pen', 'Pen', 'Pen']
# [10, 10, 10, 10, 10]

# %%
import matplotlib.pyplot as plt

# %%
labels = title
sizes = label
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','cyan']
explode = (0.1, 0, 0, 0)  # explode 1st slice
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels,loc="best")
plt.axis('equal')
# plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = title
y_pos = np.arange(len(objects))
x_pos = np.arange(len(label))
performance = label
colors=['blue','cyan','indigo','red','orange']

plt.bar(y_pos, performance, align='center',color=colors)
plt.xticks(y_pos)
plt.yticks(performance,performance)
plt.xlabel('Items')
plt.ylabel('Sales')
plt.title('Stationary Product Sales Data')

plt.show()
