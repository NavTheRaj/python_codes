# %%
new="This is my new dog"
print(new)
# Out:
# This is my new dog

# %%
with open("pie.txt","r+") as fs:
    print(fs.read())
#     num=sum(len(line.split()) for line in fs)
#     for line in fs:
#         data=fs.read()
#         print(data)
# Out:
# 10
# 20
# 30
# 40

# %%
with open("pie.txt","r+") as fr:
    labels=[]
    for number in fr:
        labels.append(int(number))

# %%
print(labels)
# Out:
# [10, 20, 30, 40]

# %%
import matplotlib.pyplot as plt

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(labels, explode=explode,colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
